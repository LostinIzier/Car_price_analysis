# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\ojasv\appdata\local\programs\python\python313\lib\site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\ojasv\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (2.4.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\ojasv\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (1.17.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\ojasv\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\ojasv\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\ojasv\appdata\local\programs\python\python313\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ojasv\appdata\local\programs\python\python313\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ojasv\appdata\local\programs\python\python313\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ojasv\appdata\local\programs\python\python313\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\ojasv\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df_cars=pd.read_csv("car_prices.csv")
df_cars
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# 1         automatic  5xyktca69fg561319    ca        5.0    9393.0   white
# 2         automatic  wba3c1c51ek116351    ca       45.0    1331.0    gray
# 3         automatic  yv1612tb4f1310987    ca       41.0   14282.0   white
# 4         automatic  wba6b2c57ed129731    ca       43.0    2641.0    gray
# ...             ...                ...   ...        ...       ...     ...
# 558832          NaN  knalw4d4xf6019304    in       45.0   18255.0  silver
# 558833    automatic  3c6td5et6cg112407    wa        5.0   54393.0   white
# 558834    automatic  5uxzw0c58cl668465    ca       48.0   50561.0   black
# 558835    automatic  1n4al3ap0fc216050    ga       38.0   16658.0   white
# 558836    automatic  1ftfw1et2eke87277    ca       34.0   15008.0    gray
#
#        interior                                             seller      mmr  \
# 0         black                            kia motors america  inc  20500.0
# 1         beige                            kia motors america  inc  20800.0
# 2         black             financial services remarketing (lease)  31900.0
# 3         black                            volvo na rep/world omni  27500.0
# 4         black             financial services remarketing (lease)  66000.0
# ...         ...                                                ...      ...
# 558832    black                                   avis corporation  35300.0
# 558833    black                                    i -5 uhlmann rv  30200.0
# 558834    black             financial services remarketing (lease)  29800.0
# 558835    black  enterprise vehicle exchange / tra / rental / t...  15100.0
# 558836     gray                   ford motor credit company llc pd  29600.0
#
#         sellingprice                                 saledate
# 0            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2            30000.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3            27750.0  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4            67000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
# ...              ...                                      ...
# 558832       33000.0  Thu Jul 09 2015 07:00:00 GMT-0700 (PDT)
# 558833       30800.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558834       34000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558835       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)
# 558836       26700.0  Thu May 28 2015 05:30:00 GMT-0700 (PDT)
#
# [558837 rows x 16 columns]

# %%
df_cars=df_cars[df_cars["state"].str.len()<3]

# %%
state_dict = {
    "ca": "California",
    "tx": "Texas",
    "pa": "Pennsylvania",
    "mn": "Minnesota",
    "az": "Arizona",
    "wi": "Wisconsin",
    "tn": "Tennessee",
    "md": "Maryland",
    "fl": "Florida",
    "ne": "Nebraska",
    "nj": "New Jersey",
    "nv": "Nevada",
    "oh": "Ohio",
    "mi": "Michigan",
    "ga": "Georgia",
    "va": "Virginia",
    "sc": "South Carolina",
    "nc": "North Carolina",
    "in": "Indiana",
    "il": "Illinois",
    "co": "Colorado",
    "ut": "Utah",
    "mo": "Missouri",
    "ny": "New York",
    "ma": "Massachusetts",
    "or": "Oregon",
    "la": "Louisiana",
    "wa": "Washington",
    "hi": "Hawaii",
    "ok": "Oklahoma",
    "ms": "Mississippi",
    "nm": "New Mexico",
    "al": "Alabama",
    "pr": "Puerto Rico",
    "qc": "Quebec",          # Canada
    "ab": "Alberta",        # Canada
    "on": "Ontario",        # Canada
    "ns": "Nova Scotia"     # Canada
}

# %%
df_cars['body'] = df_cars['body'].astype(str).str.lower().str.strip()
df_cars['body']=df_cars['body'].str.capitalize()
df_cars['transmission'] = df_cars['transmission'].astype(str).str.lower().str.strip()
df_cars['make'] = df_cars['make'].astype(str).str.lower().str.strip()
df_cars['make'] = df_cars['make'].str.capitalize()
df_cars['make'].replace(['Vw','Mercedes-Benz','Mercedes-b','Mercedes-benz'],["Volkswagen","Mercedes",'Mercedes',"Mercedes"],inplace=True)
df_cars.loc[:, "state"] = df_cars["state"].replace(state_dict)
df_cars
# Out:
# C:\Users\ojasv\AppData\Local\Temp\ipykernel_24724\1485883875.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cars['body'] = df_cars['body'].astype(str).str.lower().str.strip()
# C:\Users\ojasv\AppData\Local\Temp\ipykernel_24724\1485883875.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cars['body']=df_cars['body'].str.capitalize()
# C:\Users\ojasv\AppData\Local\Temp\ipykernel_24724\1485883875.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cars['transmission'] = df_cars['transmission'].astype(str).str.lower().str.strip()
# C:\Users\ojasv\AppData\Local\Temp\ipykernel_24724\1485883875.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cars['make'] = df_cars['make'].astype(str).str.lower().str.strip()
# C:\Users\ojasv\AppData\Local\Temp\ipykernel_24724\1485883875.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cars['make'] = df_cars['make'].str.capitalize()
# C:\Users\ojasv\AppData\Local\Temp\ipykernel_24724\1485883875.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cars['make'].replace(['Vw','Mercedes-Benz','Mercedes-b','Mercedes-benz'],["Volkswagen","Mercedes",'Mercedes',"Mercedes"],inplace=True)
# C:\Users\ojasv\AppData\Local\Temp\ipykernel_24724\1485883875.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cars['make'].replace(['Vw','Mercedes-Benz','Mercedes-b','Mercedes-benz'],["Volkswagen","Mercedes",'Mercedes',"Mercedes"],inplace=True)
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        Suv
# 1       2015     Kia              Sorento           LX        Suv
# 2       2014     Bmw             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     Bmw  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew cab
# 558834  2012     Bmw                   X5    xDrive35d        Suv
# 558835  2015  Nissan               Altima        2.5 S      Sedan
# 558836  2014    Ford                F-150          XLT  Supercrew
#
#        transmission                vin       state  condition  odometer  \
# 0         automatic  5xyktca69fg566472  California        5.0   16639.0
# 1         automatic  5xyktca69fg561319  California        5.0    9393.0
# 2         automatic  wba3c1c51ek116351  California       45.0    1331.0
# 3         automatic  yv1612tb4f1310987  California       41.0   14282.0
# 4         automatic  wba6b2c57ed129731  California       43.0    2641.0
# ...             ...                ...         ...        ...       ...
# 558832          nan  knalw4d4xf6019304     Indiana       45.0   18255.0
# 558833    automatic  3c6td5et6cg112407  Washington        5.0   54393.0
# 558834    automatic  5uxzw0c58cl668465  California       48.0   50561.0
# 558835    automatic  1n4al3ap0fc216050     Georgia       38.0   16658.0
# 558836    automatic  1ftfw1et2eke87277  California       34.0   15008.0
#
#          color interior                                             seller  \
# 0        white    black                            kia motors america  inc
# 1        white    beige                            kia motors america  inc
# 2         gray    black             financial services remarketing (lease)
# 3        white    black                            volvo na rep/world omni
# 4         gray    black             financial services remarketing (lease)
# ...        ...      ...                                                ...
# 558832  silver    black                                   avis corporation
# 558833   white    black                                    i -5 uhlmann rv
# 558834   black    black             financial services remarketing (lease)
# 558835   white    black  enterprise vehicle exchange / tra / rental / t...
# 558836    gray     gray                   ford motor credit company llc pd
#
#             mmr  sellingprice                                 saledate
# 0       20500.0       21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1       20800.0       21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2       31900.0       30000.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3       27500.0       27750.0  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4       66000.0       67000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
# ...         ...           ...                                      ...
# 558832  35300.0       33000.0  Thu Jul 09 2015 07:00:00 GMT-0700 (PDT)
# 558833  30200.0       30800.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558834  29800.0       34000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558835  15100.0       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)
# 558836  29600.0       26700.0  Thu May 28 2015 05:30:00 GMT-0700 (PDT)
#
# [558811 rows x 16 columns]

# %%
#[print(f"{x}: {df_cars[x].unique()}")for x in df_cars.columns]

# %%
#[df_cars[x].value_counts()for x in df_cars.columns]

# %%
#df_cars[(df_cars["body"]=='sedan') & (df_cars["make"]=='chevrolet')]

# %%
#df_cars["make"].unique()

# %% [markdown]
# *saledate*

# %%
df_cars=df_cars.dropna(subset=["saledate"])

# %%
df_cars["saledate"]=df_cars["saledate"].apply(
    lambda x: datetime.strptime(
        x[:24], "%a %b %d %Y %H:%M:%S"
    ).date()
)
# Out:
# C:\Users\ojasv\AppData\Local\Temp\ipykernel_24724\1310018125.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cars["saledate"]=df_cars["saledate"].apply(

# %%
df_cars["saledate"] = pd.to_datetime(df_cars["saledate"])
# Out:
# C:\Users\ojasv\AppData\Local\Temp\ipykernel_24724\632508879.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cars["saledate"] = pd.to_datetime(df_cars["saledate"])

# %%
df_cars=df_cars[df_cars["year"]<=df_cars["saledate"].dt.year]

# %%
df_cars=df_cars.reset_index()
df_cars=df_cars.drop("index",axis=1)

# %%
df_cars["vehicle_age"] = (
    df_cars["saledate"].dt.year
    + df_cars["saledate"].dt.month / 12
    + df_cars["saledate"].dt.day / 365
    - df_cars["year"]
).round(3)

# %%
#df_cars.to_csv("cleaned_data.csv",index=False)

# %%
pd.read_csv("cleaned_data.csv")
# Out:
#         year       make                model         trim       body  \
# 0       2014        Bmw             3 Series   328i SULEV      Sedan
# 1       2015      Volvo                  S60           T5      Sedan
# 2       2014        Bmw  6 Series Gran Coupe         650i      Sedan
# 3       2014        Bmw                   M5         Base      Sedan
# 4       2014  Chevrolet                Cruze          1LT      Sedan
# ...      ...        ...                  ...          ...        ...
# 558593  2015        Kia                 K900       Luxury      Sedan
# 558594  2012        Ram                 2500  Power Wagon   Crew cab
# 558595  2012        Bmw                   X5    xDrive35d        Suv
# 558596  2015     Nissan               Altima        2.5 S      Sedan
# 558597  2014       Ford                F-150          XLT  Supercrew
#
#        transmission                vin       state  condition  odometer  \
# 0         automatic  wba3c1c51ek116351  California       45.0    1331.0
# 1         automatic  yv1612tb4f1310987  California       41.0   14282.0
# 2         automatic  wba6b2c57ed129731  California       43.0    2641.0
# 3         automatic  wbsfv9c51ed593089  California       34.0   14943.0
# 4         automatic  1g1pc5sb2e7128460  California        2.0   28617.0
# ...             ...                ...         ...        ...       ...
# 558593          NaN  knalw4d4xf6019304     Indiana       45.0   18255.0
# 558594    automatic  3c6td5et6cg112407  Washington        5.0   54393.0
# 558595    automatic  5uxzw0c58cl668465  California       48.0   50561.0
# 558596    automatic  1n4al3ap0fc216050     Georgia       38.0   16658.0
# 558597    automatic  1ftfw1et2eke87277  California       34.0   15008.0
#
#          color interior                                             seller  \
# 0         gray    black             financial services remarketing (lease)
# 1        white    black                            volvo na rep/world omni
# 2         gray    black             financial services remarketing (lease)
# 3        black    black                              the hertz corporation
# 4        black    black  enterprise vehicle exchange / tra / rental / t...
# ...        ...      ...                                                ...
# 558593  silver    black                                   avis corporation
# 558594   white    black                                    i -5 uhlmann rv
# 558595   black    black             financial services remarketing (lease)
# 558596   white    black  enterprise vehicle exchange / tra / rental / t...
# 558597    gray     gray                   ford motor credit company llc pd
#
#             mmr  sellingprice    saledate  vehicle_age
# 0       31900.0       30000.0  2015-01-15        1.124
# 1       27500.0       27750.0  2015-01-29        0.163
# 2       66000.0       67000.0  2014-12-18        1.049
# 3       69000.0       65000.0  2014-12-17        1.047
# 4       11900.0        9800.0  2014-12-16        1.044
# ...         ...           ...         ...          ...
# 558593  35300.0       33000.0  2015-07-09        0.608
# 558594  30200.0       30800.0  2015-07-08        3.605
# 558595  29800.0       34000.0  2015-07-08        3.605
# 558596  15100.0       11100.0  2015-07-09        0.608
# 558597  29600.0       26700.0  2015-05-28        1.493
#
# [558598 rows x 17 columns]

# %% [markdown]
# *Highest Revenues*

# %%
g=df_cars.groupby("make")

# %%
ls={x[0]:x[1]['sellingprice'].sum() for x in g}

# %%
df_revenues=pd.DataFrame(ls.items(), columns=["make","revenue"]).set_index("make").sort_values("revenue", ascending=False)

# %%
df_revenues["revenue"] = df_revenues["revenue"].round(0)
pd.options.display.float_format = '{:,.0f}'.format

# %%
df_revenues
# Out:
#                  revenue
# make
# Ford       1,362,430,882
# Chevrolet    721,250,499
# Nissan       633,524,255
# Toyota       489,089,925
# Bmw          445,873,713
# ...                  ...
# Chev truck         2,000
# Ford truck         1,450
# Daewoo             1,200
# Dodge tk             550
# Dot                  500
#
# [64 rows x 1 columns]

# %% [markdown]
# *Driving factor*

# %%
counts={x[0]:x[1]['vin'].count() for x in g}

# %%
sale_df=pd.DataFrame(counts.items(),columns=["make","sale(no of cars)"]).set_index("make")

# %%
driving_df=pd.merge(df_revenues,sale_df,on="make")

# %%
driving_df
# Out:
#                  revenue  sale(no of cars)
# make
# Ford       1,362,430,882             93988
# Chevrolet    721,250,499             60536
# Nissan       633,524,255             54001
# Toyota       489,089,925             39966
# Bmw          445,873,713             20772
# ...                  ...               ...
# Chev truck         2,000                 1
# Ford truck         1,450                 3
# Daewoo             1,200                 3
# Dodge tk             550                 1
# Dot                  500                 1
#
# [64 rows x 2 columns]

# %% [markdown]
# *Age sale price analysis*

# %%
pd.options.display.float_format = "{:.3f}".format

# %%
g=df_cars.groupby("make")[["vehicle_age","sellingprice"]]

# %%
df_cars["proxy_profit"]=df_cars["sellingprice"]-df_cars["mmr"]

# %%
df_cars["proxy_profit_percent"]=df_cars["proxy_profit"]/df_cars["mmr"]*100

# %%
df_cars["proxy_profit_percent"]
# Out:
# 0         -5.956
# 1          0.909
# 2          1.515
# 3         -5.797
# 4        -17.647
#            ...
# 558593    -6.516
# 558594     1.987
# 558595    14.094
# 558596   -26.490
# 558597    -9.797
# Name: proxy_profit_percent, Length: 558598, dtype: float64

# %% [markdown]
# *Used-Car Depreciation Analysis (Age & Mileage Based)*

# %%
sp_va_grp=df_cars[["make","sellingprice","vehicle_age"]].groupby("make")

# %%
plot_df = (
    df_cars
    .groupby(["make", "vehicle_age"], as_index=False)["sellingprice"]
    .mean()
)

# %%
top_ten=df_cars["make"].value_counts()[0:10]

# %%
t_ten_make=pd.DataFrame(top_ten).reset_index()["make"]

# %%
plot_df_filtered = plot_df[plot_df["make"].isin(t_ten_make)]

# %%
plot_df_filtered
# Out:
#          make  vehicle_age  sellingprice
# 2240      Bmw        0.119     39029.412
# 2241      Bmw        0.124     64000.000
# 2242      Bmw        0.138     27600.000
# 2243      Bmw        0.146     30000.000
# 2244      Bmw        0.157     36305.357
# ...       ...          ...           ...
# 40128  Toyota       25.160       375.000
# 40129  Toyota       25.258       325.000
# 40130  Toyota       25.264       550.000
# 40131  Toyota       26.047       800.000
# 40132  Toyota       26.082       275.000
#
# [15692 rows x 3 columns]

# %%
plt.figure(figsize=(12, 7))

for make, grp in plot_df_filtered.groupby("make"):
    plt.plot(
        grp["vehicle_age"],
        grp["sellingprice"],
        label=make
    )

plt.xlabel("Vehicle Age (years)")
plt.ylabel("Average Selling Price")
plt.title("Used Car Depreciation: Selling Price vs Age by Make")
plt.legend(title="Make", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
window = 10 

plt.figure(figsize=(12, 7))

for make, grp in plot_df_filtered.groupby("make"):
    grp = grp.sort_values("vehicle_age")
    smoothed = grp["sellingprice"].rolling(window=window, center=True).mean()

    plt.plot(grp["vehicle_age"], smoothed, label=make)

plt.xlabel("Vehicle Age (years)")
plt.ylabel("Average Selling Price")
plt.title("Smoothed Used-Car Depreciation by Make")
plt.legend()
plt.grid(True)
plt.show()

# %%
from statsmodels.nonparametric.smoothers_lowess import lowess

plt.figure(figsize=(12, 7))

for make, grp in plot_df_filtered.groupby("make"):
    grp = grp.sort_values("vehicle_age")
    smoothed = lowess(
        grp["sellingprice"],
        grp["vehicle_age"],
        frac=0.3  # smoothing strength (0.2–0.4 works well)
    )

    plt.plot(smoothed[:, 0], smoothed[:, 1], label=make)

plt.xlabel("Vehicle Age (years)")
plt.ylabel("Average Selling Price")
plt.title("Used-Car Depreciation Trend by Make (LOWESS)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# *states contribute*

# %%
state_brand_df=df_cars.groupby(["state", "make"],as_index=False)["sellingprice"].mean()
state_brand_no_df=(df_cars.groupby(["state","make"],as_index=False).size().rename(columns={"size": "units_sold"}))
state_brand_df=pd.merge(state_brand_df,state_brand_no_df, on=["state", "make"])
#state_brand_df["avg_price"]=state_brand_df["sellingprice"]/state_brand_df["units_sold"]
state_brand_df=state_brand_df.sort_values("units_sold", ascending=False)

# %%
#profit_per_df=df_cars.groupby(["state", "make"],as_index=False)["proxy_profit_percent"].mean()

# %%
df_mixed=df_cars.groupby(["state", "make"],as_index=False)[["mmr","proxy_profit", "proxy_profit_percent","vehicle_age","odometer"]].mean()

# %%
state_brand_df=pd.merge(state_brand_df,df_mixed, on=["state", "make"])

# %%
plot_df_profits = (
    df_cars
    .groupby(["make", "vehicle_age"], as_index=False)["proxy_profit_percent"]
    .mean()
)

# %%
state_brand_df=state_brand_df[(state_brand_df["proxy_profit_percent"]>-50) & (state_brand_df["proxy_profit_percent"]<50)]

# %%
plot_df_profits_filtered = plot_df_profits[plot_df_profits["make"].isin(t_ten_make)]

# %%
window = 3

plt.figure(figsize=(12, 7))

for make, grp in plot_df_profits_filtered.groupby("make"):
    grp = grp.sort_values("vehicle_age")
    smoothed = grp["proxy_profit_percent"].rolling(window=window, center=True).mean()

    plt.plot(grp["vehicle_age"], smoothed, label=make)

plt.xlabel("Vehicle Age (years)")
plt.ylabel("Average proxy profit_precentage")
plt.title("Smoothed Used-Car Depreciation by Make")
plt.legend()
plt.grid(True)
plt.show()

# %%
from statsmodels.nonparametric.smoothers_lowess import lowess

plt.figure(figsize=(12, 7))

for make, grp in plot_df_profits_filtered.groupby("make"):
    grp = grp.sort_values("vehicle_age")
    smoothed = lowess(
        grp["proxy_profit_percent"],
        grp["vehicle_age"],
        frac=0.3  
    )

    plt.plot(smoothed[:, 0], smoothed[:, 1], label=make)

plt.xlabel("Vehicle Age (years)")
plt.ylabel("Average proxy profit_precentage ")
plt.title("Used-Car Depreciation Trend by Make (LOWESS)")
plt.legend()
plt.grid(True)
plt.show()

# %%
max_rev_per_state=(state_brand_df.loc[state_brand_df.groupby("state")["sellingprice"].idxmax()].reset_index(drop=True))

# %%
max_rev_per_state.rename(columns={"sellingprice": "total_sale_amt"}, inplace=True)

# %%
max_rev_per_state
# Out:
#              state       make  total_sale_amt  units_sold  avg_price
# 0          Alabama      Dodge          50,300           4     12,575
# 1          Alberta       Ford       3,294,300         245     13,446
# 2          Arizona  Chevrolet      16,370,425        1388     11,794
# 3       California        Bmw     123,979,971        5569     22,263
# 4         Colorado       Ford      26,440,356        1535     17,225
# 5          Florida       Ford     147,442,337       10731     13,740
# 6          Georgia       Ford      74,701,568        5091     14,673
# 7           Hawaii       Ford       2,469,400         197     12,535
# 8         Illinois       Ford      98,432,233        5717     17,217
# 9          Indiana      Honda       7,629,150         395     19,314
# 10       Louisiana  Chevrolet       4,417,553         400     11,044
# 11        Maryland       Ford      17,918,725        1686     10,628
# 12   Massachusetts       Ford       6,286,050         828      7,592
# 13        Michigan       Ford      92,472,825        5578     16,578
# 14       Minnesota       Ford      37,715,285        2427     15,540
# 15     Mississippi       Ford       6,172,200         449     13,747
# 16        Missouri       Ford      93,527,582        5457     17,139
# 17        Nebraska  Chevrolet      11,726,979         870     13,479
# 18          Nevada        Bmw      22,709,225         955     23,779
# 19      New Jersey       Ford      57,292,447        4044     14,167
# 20      New Mexico       Ford         256,250          34      7,537
# 21        New York       Ford      33,530,826        2095     16,005
# 22  North Carolina  Chevrolet      29,873,903        3226      9,260
# 23     Nova Scotia        Nan         161,100          15     10,740
# 24            Ohio        Bmw      55,385,300        1502     36,874
# 25        Oklahoma       Ford         169,150          26      6,506
# 26         Ontario      Dodge      13,163,850         644     20,441
# 27          Oregon  Chevrolet       2,655,475         221     12,016
# 28    Pennsylvania       Ford     104,080,005        6447     16,144
# 29     Puerto Rico     Toyota       6,234,600         536     11,632
# 30          Quebec       Ford       8,426,600         417     20,208
# 31  South Carolina  Chevrolet       9,000,308         764     11,781
# 32       Tennessee       Ford      98,666,302        5306     18,595
# 33           Texas       Ford     140,500,857        9573     14,677
# 34            Utah       Ford       7,652,065         484     15,810
# 35        Virginia       Ford      13,493,700        1541      8,756
# 36      Washington       Ford      17,148,787        1117     15,353
# 37       Wisconsin   Mercedes      19,455,275         724     26,872

# %%
state_group=df_cars.groupby("state")

state_rev={x[0]:x[1]["sellingprice"].sum() for x in state_group}

total_state_sale_df=pd.DataFrame(state_rev.items(),columns=["state","total_sales"]).set_index("state").sort_values("total_sales",ascending=False)

no_of_cars={x[0]:x[1]['vin'].count()for x in state_group}

cars_state_df=pd.DataFrame(no_of_cars.items(),columns=["state","no_of_cars"]).set_index("state")

cars_state_df=pd.merge(total_state_sale_df,cars_state_df,on="state")

cars_state_df["avg_val"]=cars_state_df["total_sales"]/cars_state_df["no_of_cars"]

cars_state_df.sort_values("avg_val",ascending=False)
# Out:
#                  total_sales  no_of_cars  avg_val
# state
# Ontario           61,311,050        3442   17,813
# Tennessee        355,114,508       20887   17,002
# Pennsylvania     860,898,673       53897   15,973
# Colorado         123,406,585        7773   15,876
# Nevada           191,337,588       12675   15,096
# Michigan         230,847,627       15509   14,885
# Illinois         347,247,026       23477   14,791
# California     1,059,880,927       73089   14,501
# Missouri         231,647,138       16013   14,466
# Ohio             309,924,510       21543   14,386
# Wisconsin        137,880,166        9849   13,999
# Washington       103,419,009        7416   13,945
# Florida        1,150,281,156       82919   13,872
# Minnesota        129,254,486        9429   13,708
# New Jersey       378,102,350       27783   13,609
# Quebec            16,549,750        1245   13,293
# Texas            606,092,911       45898   13,205
# Georgia          448,829,714       34744   12,918
# Nebraska          50,356,175        4011   12,555
# Hawaii            15,080,050        1237   12,191
# Utah              22,152,489        1836   12,066
# Oregon            13,350,050        1155   11,558
# Arizona          100,737,770        8735   11,533
# New York          64,823,485        5699   11,375
# Mississippi       20,812,885        1851   11,244
# Alberta           10,367,650         928   11,172
# Indiana           46,329,050        4323   10,717
# Louisiana         23,044,363        2190   10,523
# South Carolina    43,818,258        4246   10,320
# Nova Scotia          623,000          61   10,213
# Puerto Rico       25,644,350        2725    9,411
# Alabama              237,700          26    9,142
# North Carolina   189,157,093       21842    8,660
# Virginia         103,068,020       12023    8,573
# Maryland          82,441,725       11150    7,394
# Oklahoma             498,100          72    6,918
# Massachusetts     45,264,250        6729    6,727
# New Mexico         1,075,900         171    6,292

# %%
state_players={x[0]:x[1]["make"].value_counts() for x in state_group}

# %%
df=pd.DataFrame(state_players)

# %%
big_player={}
for col in df.columns:
    big_player[col]={
         "max_brand_by_no": df[col].idxmax(),
        "max_no": df[col].max()
    }

# %%
big_player_df=pd.DataFrame(big_player).transpose()

# %%
# Out:
#                max_brand_by_no    max_no
# Florida                   Ford 10731.000
# Texas                     Ford  9573.000
# California                Ford  8904.000
# Pennsylvania              Ford  6447.000
# Illinois                  Ford  5717.000
# Michigan                  Ford  5578.000
# Missouri                  Ford  5457.000
# Tennessee                 Ford  5306.000
# Georgia                   Ford  5091.000
# New Jersey              Nissan  4434.000
# Ohio                      Ford  3407.000
# North Carolina            Ford  3251.000
# Minnesota                 Ford  2427.000
# New York                  Ford  2095.000
# Maryland                  Ford  1686.000
# Virginia                  Ford  1541.000
# Nevada                    Ford  1538.000
# Colorado                  Ford  1535.000
# Wisconsin            Chevrolet  1424.000
# Arizona              Chevrolet  1388.000
# Washington                Ford  1117.000
# Nebraska             Chevrolet   870.000
# Massachusetts           Toyota   867.000
# Indiana              Chevrolet   802.000
# South Carolina       Chevrolet   764.000
# Ontario                  Dodge   644.000
# Puerto Rico             Toyota   536.000
# Utah                      Ford   484.000
# Mississippi               Ford   449.000
# Quebec                    Ford   417.000
# Louisiana                 Ford   408.000
# Alberta                   Ford   245.000
# Oregon               Chevrolet   221.000
# Hawaii                    Ford   197.000
# New Mexico                Ford    34.000
# Oklahoma                  Ford    26.000
# Nova Scotia                Nan    15.000
# Alabama                   Ford     6.000
